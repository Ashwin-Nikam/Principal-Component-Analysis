# %% [markdown]
# #### Library for Generating Plots

# %%
library(ggplot2)

# %% [markdown]
# #### Dataset 1

# %% [markdown]
# ##### Reading CSV for PCA

# %%
df1<-read.csv(file="PCA1.csv",head=FALSE,sep=",")
# Code to remove the first row
df1<-df1[-c(1),]
df1
# Out:
#     V1  V2          V3          V4
# 2    0  -1.1050198   1.00300057 Asthma
# 3    1  -1.5669561   0.63101901 Arrhythmia
# 4    2   1.8066905  -1.02243763 Hypertension
# 5    3  -1.6431772   1.32499840 Arrhythmia
# 6    4   1.9339774  -1.17718001 Hypertension
# 7    5  -1.4354156   0.63068040 Arrhythmia
# 8    6   2.0313548  -0.97753766 Hypertension
# 9    7  -1.5424755   0.87610143 Arrhythmia
# 10   8  -0.6753447   1.01106066 Asthma
# 11   9  -1.3235108   0.26559050 Arrhythmia
# 12  10  -1.1964984   0.58503885 Arrhythmia
# 13  11  -0.6017263   0.65860984 Asthma
# 14  12  -0.3928177  -0.01783056 Asthma
# 15  13   2.0883704  -1.21440072 Hypertension
# 16  14  -1.7189991   0.64319347 Arrhythmia
# 17  15   1.6956338  -1.12259966 Hypertension
# 18  16  -0.6687470   0.27176272 Asthma
# 19  17  -0.6825754   0.31551639 Asthma
# 20  18  -1.0721876   0.26083218 Asthma
# 21  19   1.9989453  -1.02550956 Hypertension
# 22  20  -1.4451217   0.49009975 Arrhythmia
# ...

# %% [markdown]
# ##### PCA plot for Dataset 1

# %%
ggplot(data=df1, aes(x=V2, y=V3,colour=V4)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# ##### Reading CSV for SVD

# %%
df2<-read.csv(file="SVD1.csv",head=FALSE,sep=",")
df2<-df2[-c(1),]
df2
# Out:
#     V1  V2        V3          V4
# 2    0   8.884672 -1.1825106  Asthma
# 3    1   9.749951 -1.2220163  Arrhythmia
# 4    2   6.656607  1.9789137  Hypertension
# 5    3  10.795645 -1.3609261  Arrhythmia
# 6    4   5.942684  1.9752442  Hypertension
# 7    5   9.977078 -0.9283062  Arrhythmia
# 8    6   6.638854  2.1402926  Hypertension
# 9    7  10.735436 -1.0867750  Arrhythmia
# 10   8   8.774445 -0.7727551  Asthma
# 11   9   9.238428 -0.9212069  Arrhythmia
# 12  10   9.153567 -1.0010234  Arrhythmia
# 13  11   9.283364 -0.4202207  Asthma
# 14  12   8.404226 -0.1378820  Asthma
# 15  13   6.592980  2.2971059  Hypertension
# 16  14  10.460205 -1.1140607  Arrhythmia
# 17  15   6.735909  1.9728208  Hypertension
# 18  16   8.604398 -0.5074065  Asthma
# 19  17   8.904104 -0.4306446  Asthma
# 20  18   9.157599 -0.6808772  Asthma
# 21  19   6.565386  2.1126743  Hypertension
# 22  20   9.851014 -1.0099665  Arrhythmia
# 23  21   6.351341  1.8162423  Hypertension
# ...

# %% [markdown]
# ##### SVD plot for Dataset 1

# %%
ggplot(data=df2, aes(x=V2, y=V3,colour=V4)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# ##### Reading CSV for TSNE

# %%
df3<-read.csv(file="TSNE1.csv",head=FALSE,sep=",")
df3<-df3[-c(1),]
df3
# Out:
#     V1  V2           V3          V4
# 2    0   -26.5072594 -27.732358  Asthma
# 3    1   -47.7393612  15.046735  Arrhythmia
# 4    2     6.5747740  53.466162  Hypertension
# 5    3   -38.5584521  49.814646  Arrhythmia
# 6    4    -8.6170231  48.564739  Hypertension
# 7    5   -47.6404822  -5.347309  Arrhythmia
# 8    6     5.3583560  45.357171  Hypertension
# 9    7   -61.7509861  22.751536  Arrhythmia
# 10   8   -49.3334604 -35.318297  Asthma
# 11   9   -34.0847348 -56.783930  Arrhythmia
# 12  10   -17.3151607 -29.375238  Arrhythmia
# 13  11    12.5634687 -23.761673  Asthma
# 14  12    41.3872262 -62.005570  Asthma
# 15  13   -12.4464299  73.797104  Hypertension
# 16  14   -61.0907409   4.131424  Arrhythmia
# 17  15    10.7246209 -32.548694  Hypertension
# 18  16   -72.4319506  31.925100  Asthma
# 19  17    32.1836145 -52.484576  Asthma
# 20  18     5.8208505 -62.609507  Asthma
# 21  19    19.7913979  51.961822  Hypertension
# 22  20   -45.1015029 -13.777494  Arrhythmia
# ...

# %% [markdown]
# ##### TSNE plot for Dataset 1

# %%
ggplot(data=df3, aes(x=V2, y=V3,colour=V4)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# #### Dataset 2

# %% [markdown]
# ##### Reading CSV for PCA

# %%
df4<-read.csv(file="PCA2.csv",head=FALSE,sep=",")
df4<-df4[-c(1),]
df4
# Out:
#     V1  V2          V3           V4
# 2    0  -0.64747335  0.319902015 Septic
# 3    1   0.77779375 -0.070212075 HVD
# 4    2   0.85278351 -0.433194215 HVD
# 5    3  -0.85720623  0.391162282 Septic
# 6    4   1.27729239 -0.079904780 TB
# 7    5  -0.07180227 -0.583308195 CD
# 8    6   0.90882826 -0.195973611 TB
# 9    7  -0.20573718  0.120892909 CD
# 10   8   0.39541687  1.057457108 Septic
# 11   9  -0.38963052  0.320628291 Septic
# 12  10   0.90429334 -0.018196953 TB
# 13  11   0.41150474  0.586540350 Septic
# 14  12  -0.01160593 -0.536538160 Septic
# 15  13   0.64819903 -0.294559238 HVD
# 16  14  -0.44901190 -0.225907492 CD
# 17  15   0.63028509 -0.138284789 HVD
# 18  16   0.19680320 -0.507752553 CD
# 19  17  -0.67127263  0.684613325 Septic
# 20  18   0.18706266  0.003751204 CD
# 21  19  -0.36762331 -0.130266534 TB
# 22  20   0.98917024 -0.310985365 HVD
# 23  21  -0.70974265  0.040137058 CD
# 24  22   1.24416111  0.460294185 HVD
# 25  23   1.36258436 -0.079976603 HVD
# ...

# %% [markdown]
# ##### PCA plot for Dataset 2

# %%
ggplot(data=df4, aes(x=V2, y=V3,colour=V4)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# ##### Reading CSV for SVD

# %%
df5<-read.csv(file="SVD2.csv",head=FALSE,sep=",")
df5<-df5[-c(1),]
df5
# Out:
#     V1  V2           V3          V4
# 2    0   3.068655386 -0.56749338 Septic
# 3    1  -0.556290181  3.31372862 HVD
# 4    2  -0.671835888  3.58872112 HVD
# 5    3   2.832063672 -0.59151272 Septic
# 6    4   0.910435968  1.11769321 TB
# 7    5   1.416936065  0.91346897 CD
# 8    6  -0.123889456  2.25987268 TB
# 9    7   1.442766186  0.84741379 CD
# 10   8   1.998427380  0.85964942 Septic
# 11   9   1.902441921  0.10284923 Septic
# 12  10   1.209195583  0.20931569 TB
# 13  11   1.381499912  0.33369726 Septic
# 14  12   1.962395627  0.50544926 Septic
# 15  13  -0.245314246  3.13775953 HVD
# 16  14   1.905956529  0.85660481 CD
# 17  15  -0.140077063  3.10544468 HVD
# 18  16   0.861704431  1.59497850 CD
# 19  17   2.724006885 -0.90800951 Septic
# 20  18   0.810639703  1.46559999 CD
# 21  19   1.816867011 -0.16931255 TB
# 22  20   0.223827648  2.90387467 HVD
# 23  21   2.114401653  0.02279387 CD
# 24  22   0.007223646  1.60221920 HVD
# 25  23  -0.747284418  3.03884722 HVD
# ...

# %% [markdown]
# ##### SVD plot for Dataset 2

# %%
ggplot(data=df5, aes(x=V2, y=V3,colour=V4)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# ##### Reading CSV for TSNE

# %%
df6<-read.csv(file="TSNE2.csv",head=FALSE,sep=",")
df6<-df6[-c(1),]
df6
# Out:
#     V1  V2          V3          V4
# 2    0  -13.1955411 -23.9695613 Septic
# 3    1    7.0562555  24.4718433 HVD
# 4    2   -2.4935487  30.8365678 HVD
# 5    3   -5.4781497 -24.0561266 Septic
# 6    4   22.5326721   0.3480895 TB
# 7    5  -15.7301035   7.3357724 CD
# 8    6   11.9942585  16.8941702 TB
# 9    7  -12.4394848   6.0174122 CD
# 10   8   27.2477640   5.5615345 Septic
# 11   9   -1.7230173 -13.6996445 Septic
# 12  10   18.4443983   7.8006704 TB
# 13  11   24.3849224   8.1787168 Septic
# 14  12   13.3798016  -7.1301450 Septic
# 15  13    7.3516581  25.8819986 HVD
# 16  14   -6.3600815  -6.7264938 CD
# 17  15    3.3144443  25.8513385 HVD
# 18  16   -7.0107072  17.2412826 CD
# 19  17   -6.5939101 -20.8162690 Septic
# 20  18   -2.4708250  13.5505309 CD
# 21  19   -0.1028683 -20.2749663 TB
# 22  20   10.2654843  23.0833153 HVD
# 23  21   -5.2249965 -10.4332887 CD
# 24  22   12.5080244  12.5010444 HVD
# 25  23   13.1655391  21.1134189 HVD
# 26  24   -6.6307120  17.0377214 CA
# ...

# %% [markdown]
# ##### TSNE plot for Dataset 2

# %%
ggplot(data=df6, aes(x=V2, y=V3,colour=V4)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# #### Dataset 3

# %% [markdown]
# ##### Reading CSV for PCA

# %%
df7<-read.csv(file="PCA3.csv",head=FALSE,sep=",")
df7<-df7[-c(1),]
df7
# Out:
#     V1  V2           V3           V4
# 2    0   0.07598263   0.585077572 Obesity
# 3    1   0.34485964  -0.155314070 Diabetes
# 4    2   0.36682403   0.222721633 Obesity
# 5    3   0.47525047   3.623262341 ALL
# 6    4   0.49823779  -0.876490935 COPD
# 7    5   0.06105893  -0.177454446 Diabetes
# 8    6   0.21446259   0.356865347 Obesity
# 9    7   0.43477708  -0.598977036 Diabetes
# 10   8   0.44653286  -0.137951583 Diabetes
# 11   9   0.35981483  -0.006837879 Diabetes
# 12  10  -0.80509478  -0.066355737 AML
# 13  11   0.02035979   0.612067973 ALL
# 14  12   0.29216677   0.421896146 Obesity
# 15  13   0.11188723   3.216918156 ALL
# 16  14  -0.13973585   1.082370524 Obesity
# 17  15   0.34772229   0.203662258 Obesity
# 18  16   0.54845440   1.828915204 ALL
# 19  17   0.30923516  -0.297408774 Diabetes
# 20  18   0.66794959  -0.346023336 COPD
# 21  19   0.37012028  -0.067660567 Diabetes
# 22  20   0.50821407   0.505470566 Obesity
# 23  21   0.28984384  -0.346412168 Diabetes
# ...

# %% [markdown]
# ##### PCA plot for Dataset 3

# %%
ggplot(data=df7, aes(x=V2, y=V3,colour=V4)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# ##### Reading CSV for SVD

# %%
df8<-read.csv(file="SVD3.csv",head=FALSE,sep=",")
df8<-df8[-c(1),]
df8
# Out:
#     V1  V2        V3           V4
# 2    0  3.999689  -0.61300683  Obesity
# 3    1  3.535697  -0.10431595  Diabetes
# 4    2  3.366456  -0.33441612  Obesity
# 5    3  9.027071  -5.25642104  ALL
# 6    4  3.975320   0.32315310  COPD
# 7    5  4.252951  -0.14198045  Diabetes
# 8    6  4.746812  -0.79417207  Obesity
# 9    7  3.822375   0.25889194  Diabetes
# 10   8  3.182150   0.13089054  Diabetes
# 11   9  2.808457  -0.10321544  Diabetes
# 12  10  7.084607   0.59843273  AML
# 13  11  4.540060  -0.78962531  ALL
# 14  12  3.947885  -0.57295488  Obesity
# 15  13  8.677217  -4.24215645  ALL
# 16  14  5.530788  -1.36910647  Obesity
# 17  15  3.966999  -0.31614889  Obesity
# 18  16  7.171358  -2.75288028  ALL
# 19  17  3.518545   0.10550030  Diabetes
# 20  18  3.699997  -0.07424427  COPD
# 21  19  3.485751  -0.11407677  Diabetes
# 22  20  3.877710  -0.67703639  Obesity
# 23  21  3.139284   0.23949940  Diabetes
# 24  22  7.633739   0.09882279  AML
# ...

# %% [markdown]
# ##### SVD plot for Dataset 3

# %%
ggplot(data=df8, aes(x=V2, y=V3,colour=V4)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# ##### Reading CSV for TSNE

# %%
df9<-read.csv(file="TSNE3.csv",head=FALSE,sep=",")
df9<-df9[-c(1),]
df9
# Out:
#     V1  V2           V3          V4
# 2    0    3.63996358 -28.3441806 Obesity
# 3    1  -17.99814851 -36.7782969 Diabetes
# 4    2   -3.16214190 -34.0173352 Obesity
# 5    3   -1.93610479 -10.0307789 ALL
# 6    4  -22.71148105 -29.1487974 COPD
# 7    5  -26.58985538 -31.4503757 Diabetes
# 8    6    3.81462033 -21.3164131 Obesity
# 9    7  -21.23169818 -30.7358457 Diabetes
# 10   8   -9.86661497 -39.6684823 Diabetes
# 11   9   -3.84880935 -41.9227376 Diabetes
# 12  10   12.29588030  -7.7304946 AML
# 13  11    4.21135102 -22.3350665 ALL
# 14  12    0.08517523 -26.6392516 Obesity
# 15  13    0.37245183 -10.5178032 ALL
# 16  14    8.13103308 -18.2809286 Obesity
# 17  15    0.60218340 -28.0432611 Obesity
# 18  16    2.78990817 -13.4234353 ALL
# 19  17  -15.35849806 -33.5411084 Diabetes
# 20  18  -18.66627224 -23.7932523 COPD
# 21  19  -10.58699303 -35.3222102 Diabetes
# 22  20   -1.65323156 -22.1439524 Obesity
# 23  21  -13.02379512 -44.9833686 Diabetes
# ...

# %% [markdown]
# ##### TSNE plot for Dataset 3

# %%
ggplot(data=df9, aes(x=V2, y=V3,colour=V4)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# #### Dataset 4 - Demo

# %% [markdown]
# ##### Reading CSV for PCA

# %%
df10<-read.csv(file="PCA_Demo.csv",head=FALSE,sep=",")
df10<-df10[-c(1),]
df10
# Out:
#     V1 V2          V3           V4
# 2    0  0.11904411 -0.065938747 ALL
# 3    1  0.14954659 -0.033007864 ALL
# 4    2  0.12198843 -0.075934445 ALL
# 5    3 -0.05590799 -0.072170966 AML
# 6    4 -0.08433602  0.088120776 Breast Cancer
# 7    5  0.11883063 -0.015719328 ALL
# 8    6 -0.06068844 -0.120106487 AML
# 9    7  0.06809629 -0.072107841 ALL
# 10   8 -0.01378730  0.007814556 Breast Cancer
# 11   9  0.25514484 -0.141444571 ALL
# 12  10 -0.17615390  0.185083004 Breast Cancer
# 13  11  0.07251874 -0.027909065 ALL
# 14  12 -0.02831292  0.054510128 Breast Cancer
# 15  13 -0.04037048 -0.005762156 ALL
# 16  14  0.01680718 -0.037292449 ALL
# 17  15 -0.09482195  0.067492991 Breast Cancer
# 18  16  0.18626976 -0.040002523 ALL
# 19  17 -0.09990996  0.100986999 Breast Cancer
# 20  18 -0.03568472  0.026579713 Breast Cancer
# 21  19 -0.17049413  0.082886327 Breast Cancer
# 22  20  0.16650720 -0.089296291 Colon Cancer
# 23  21 -0.02223285  0.036552220 ALL
# ...

# %% [markdown]
# ##### PCA plot for Dataset 4

# %%
ggplot(data=df10, aes(x=V2, y=V3,colour=V4)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# ##### Reading CSV for SVD

# %%
df11<-read.csv(file="SVD_Demo.csv",head=FALSE,sep=",")
df11<-df11[-c(1),]
df11
# Out:
#     V1 V2       V3          V4
# 2    0 5.100086  1.00294412 ALL
# 3    1 5.100209  0.71173754 ALL
# 4    2 5.124825  0.87872941 ALL
# 5    3 4.890599 -0.33494495 AML
# 6    4 5.045806 -0.67786486 Breast Cancer
# 7    5 4.966163  0.35031793 ALL
# 8    6 4.988788  0.03451687 AML
# 9    7 5.118238  0.92320345 ALL
# 10   8 4.880826 -0.42669601 Breast Cancer
# 11   9 5.066977  1.22929849 ALL
# 12  10 5.221119 -0.41618177 Breast Cancer
# 13  11 5.086408  0.79765180 ALL
# 14  12 5.022832 -0.45018525 Breast Cancer
# 15  13 5.064977  0.50597998 ALL
# 16  14 4.921652  0.34205017 ALL
# 17  15 4.925192 -0.51762500 Breast Cancer
# 18  16 5.116915  1.00385488 ALL
# 19  17 4.905160 -0.44702644 Breast Cancer
# 20  18 4.887918 -0.56251170 Breast Cancer
# 21  19 5.091420 -0.74708854 Breast Cancer
# 22  20 4.858718 -0.29984147 Colon Cancer
# 23  21 5.182587  0.74593116 ALL
# 24  22 5.088394 -0.86944288 Breast Cancer
# 25  23 5.020020 -0.04772274 AML
# 26  24 4.987203 -0.44098117 Colon Cancer
# ...

# %% [markdown]
# ##### SVD plot for Dataset 4

# %%
ggplot(data=df11, aes(x=V2, y=V3,colour=V4)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# ##### Reading CSV for TSNE

# %%
df12<-read.csv(file="TSNE_Demo.csv",head=FALSE,sep=",")
df12<-df12[-c(1),]
df12
# Out:
#     V1 V2          V3          V4
# 2    0 -17.6553850  20.448357  ALL
# 3    1 -47.3010683  64.265305  ALL
# 4    2 -65.5607073  24.200980  ALL
# 5    3  10.9453096  44.387467  AML
# 6    4  52.3037133 -10.334567  Breast Cancer
# 7    5 -53.8974777  -3.142589  ALL
# 8    6 -14.9985842 -91.458391  AML
# 9    7 -70.0148547  47.447369  ALL
# 10   8  39.8062066  37.943673  Breast Cancer
# 11   9 -81.6914219  24.419048  ALL
# 12  10  34.9039839 -12.722152  Breast Cancer
# 13  11 -26.8692236  40.882362  ALL
# 14  12  26.7632673 -49.007131  Breast Cancer
# 15  13 -27.4173652  16.020496  ALL
# 16  14 -45.2263885  24.741670  ALL
# 17  15  -0.1980276 -12.029468  Breast Cancer
# 18  16 -81.5545617   8.614081  ALL
# 19  17   5.2960725   9.526920  Breast Cancer
# 20  18  37.4946674  27.417933  Breast Cancer
# 21  19  31.8533757   0.444991  Breast Cancer
# 22  20  14.3806427  75.366722  Colon Cancer
# 23  21 -42.8665269 -34.880675  ALL
# 24  22  17.9116662 -28.528523  Breast Cancer
# ...

# %% [markdown]
# ##### TSNE plot for Dataset 4

# %%
ggplot(data=df12, aes(x=V2, y=V3,colour=V4)) + geom_point()
# Out:
# plot without title
